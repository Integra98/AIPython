# %%
#polynomial regression

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# %%
# def f(x):
#     return x*np.sin(pow(x,2))
sc_df = pd.read_csv('LogDeepLearning_v.1.0.csv', encoding='latin1')
sc_df.keys()
keys=np.array(sc_df.keys()) 
n=1
ka=np.array(keys.shape)
scnum=sc_df.loc[n,keys[1:ka[0]-1]]
y=np.array(scnum)
x=keys[1:ka[0]-1]
x = [int(i) for i in x]
x=np.array(x)
plt.plot(x,y,'ob')

# %%
plt.plot(x,y,'ob')

# %%
X=x[:,np.newaxis] 
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
#degree=3
colors=['silver','teal','magenta','gray']
# plt.scatter(X, y,  color='cyan', marker='o', label='point')
degree=1
count=1
for count,degree in enumerate ([2,3,7,9]):
    poly=make_pipeline(PolynomialFeatures(degree),Ridge())
    poly.fit(X_train,y_train)
    y_pred=poly.predict(X_train)
    print('degree= %d' %degree)
    print('MSE= %.2f' % mean_squared_error(y_train,y_pred))
    print('variance = %.2f' % r2_score(y_train,y_pred))
    h=poly.predict(X)
    plt.scatter(X_train,y_train,color='black', marker='o', label='train point')
    plt.scatter(X_test,y_test,color='red', marker='o', label='test point')

    plt.plot(X,h,color=colors[count], label='degree=%d' %degree)
    plt.legend(loc='upper left')
# Out:
# degree= 2
# MSE= 354141.90
# variance = 0.38
# degree= 3
# MSE= 146333.20
# variance = 0.75
# degree= 7
# MSE= 37011.19
# variance = 0.94
# degree= 9
# MSE= 17160.85
# variance = 0.97
# C:\Users\Mi Notebook\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.605578e-17
#   overwrite_a=True).T
# C:\Users\Mi Notebook\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.472252e-44
#   overwrite_a=True).T
